# %%
# Sampling in Python

# %%
import pandas as pd
import numpy as np

# Sample 1000 rows from spotify_population
sales_df = pd.read_csv('Data/sales.csv')
sales_df.columns = sales_df.columns.str.strip()
sales_sample = sales_df.sample(n=1000)

# Print the sample
print(sales_sample)
# Out:
#          country order_value_EUR       cost        date     category  \
# 901      Finland      194,531.02  158970.75    7/9/2019     Clothing
# 978      Finland      125,851.79  103777.39  11/15/2020        Games
# 872     Portugal       74,790.02   64992.53   6/19/2020       Beauty
# 404      Finland       53,616.06   45589.74    1/3/2020   Appliances
# 459       Sweden      113,586.11   91641.27   2/19/2019     Outdoors
# ..           ...             ...        ...         ...          ...
# 15        Sweden       54,078.92   46102.28   11/8/2020        Books
# 584  Netherlands      200,472.46  170181.07   6/19/2020  Electronics
# 285     Portugal      228,961.30  183764.34    6/1/2020   Appliances
# 319           UK      151,632.33  120744.82   7/14/2020     Clothing
# 389     Portugal       77,087.84   65894.69   5/17/2020        Other
#
#                      customer_name    sales_manager           sales_rep  \
# 901  Farrell, Swaniawski and Crist       Hube Corey    Mellicent Mattys
# 978                     Wunsch LLC       Hube Corey    Mellicent Mattys
# 872                Corwin and Sons  Celine Tumasian       Corene Shirer
# 404                       Kihn Inc       Hube Corey         Wat Bowkley
# 459               Labadie and Sons     Maxie Marrow  Tarrah Castelletti
# ..                             ...              ...                 ...
# 15                Tillman and Sons     Maxie Marrow        Anita Woakes
# 584                  Wiza and Sons    Denice Amberg      Nero Harbisher
# 285                 Johns and Sons  Celine Tumasian    Hortense Gerring
# 319               Armstrong-Little  Jessamine Apark        Winny Agnolo
# 389    Rowe, Hermiston and Kessler  Celine Tumasian        Aurelie Wren
#
#     device_type    order_id
# 901      Tablet  21-8525376
# 978          PC  03-6962760
# 872          PC  82-2840501
# 404          PC  84-4478396
# 459      Mobile  48-8166416
# ..          ...         ...
# 15           PC  08-7576451
# 584          PC  98-5774102
# 285          PC  37-8204282
# 319          PC  89-5350599
# 389          PC  51-5334556
#
# [1000 rows x 10 columns]

# %%
print(sales_df.head())
# Out:
#     country order_value_EUR       cost        date  category  \
# 0    Sweden       17,524.02   14122.61   2/12/2020     Books
# 1   Finland      116,563.40   92807.78   9/26/2019     Games
# 2  Portugal      296,465.56  257480.34   7/11/2019  Clothing
# 3  Portugal       74,532.02   59752.32    4/2/2020    Beauty
# 4     Spain      178,763.42  146621.76  12/22/2019     Games
#
#        customer_name    sales_manager           sales_rep device_type  \
# 0    Goldner-Dibbert     Maxie Marrow       Madelon Bront      Mobile
# 1   Hilll-Vandervort       Hube Corey         Wat Bowkley      Mobile
# 2     Larkin-Collier  Celine Tumasian  Smitty Culverhouse          PC
# 3  Hessel-Stiedemann  Celine Tumasian        Aurelie Wren          PC
# 4     Johns and Sons     Emalia Dinse     Bertha Walbrook      Tablet
#
#      order_id
# 0  70-0511466
# 1  28-6585323
# 2  58-7703341
# 3  14-6700183
# 4  15-8765160

# %%
# Calculate the mean cost from sales_df (population)
mean_cost_pop = sales_df['cost'].mean()

# Calculate the mean cost from sales_sample
mean_cost_samp = sales_sample['cost'].mean()

# Print the means
print('Mean cost of population:', mean_cost_pop)
print('Mean cost of sample:', mean_cost_samp)
# Out:
# Mean cost of population: 94369.31099000001
# Mean cost of sample: 94369.31099

# %%
# Create a pandas Series from the cost column of sales_df
cost_pop = sales_df['cost']
# Sample 100 values of cost_pop
cost_samp = cost_pop.sample(n=100)
# Calculate the mean of cost_pop
mean_cost_pop = np.mean(cost_pop)
# Calculate the mean of cost_samp
mean_cost_samp = np.mean(cost_samp)
print(mean_cost_pop)
print(mean_cost_samp)
# Out:
# 94369.31099000001
# 102946.6153
